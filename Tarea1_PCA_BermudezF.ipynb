# %% [markdown]
# Estadística Multivariada
# Tarea 1
#
# Profesor: Julio César Galindo López
#
# Nombre: Bermúdez Cadena Fernanda
#
# Clave ULSA: 210249
#
# ACT 600

# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
import pandas as pd

X = [[0, 0], [0, 1], [2, 1], [3, 4], [5, 2]]

X_df = pd.DataFrame(data=X, columns=['Coordenada x', 'Coordenada y'])

labels = ['P1', 'P2', 'P3', 'P4', 'P5']

X_df['Label'] = labels

X_df.head()
# Out:
#    Coordenada x  Coordenada y Label
# 0             0             0    P1
# 1             0             1    P2
# 2             2             1    P3
# 3             3             4    P4
# 4             5             2    P5

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X = X_df.drop(columns=['Label'])
y = X_df['Label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

print("X_train.shape, y_train.shape:", X_train.shape, y_train.shape)
print("X_test.shape, y_test.shape:", X_test.shape, y_test.shape)
# Out:
# X_train.shape, y_train.shape: (3, 2) (3,)
# X_test.shape, y_test.shape: (2, 2) (2,)

# %%
import matplotlib.pyplot as plt

plt.scatter(X_df.iloc[:, 0], X_df.iloc[:, 1], marker="o", alpha=0.8, color='green')

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Coordenada x', fontsize=15)
plt.ylabel('Coordenada y', fontsize=15)

plt.grid()
plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

print("PCA train shape:", X_train_pca.shape)
print("PCA test shape:", X_test_pca.shape)
# Out:
# PCA train shape: (3, 2)
# PCA test shape: (2, 2)

# %%
import numpy as np
import matplotlib.pyplot as plt

X_train_pca_label_0 = np.array([x for x, y in zip(X_train_pca, y_train) if y == 0])
X_train_pca_label_1 = np.array([x for x, y in zip(X_train_pca, y_train) if y == 1])

plt.figure(figsize=(6, 5))

plt.plot(X_train[:, 0], X_train[:, 1], "o", alpha=0.8, label='Original', color='green')
plt.plot(X_train_pca[:, 0], X_train_pca[:, 1], "+", alpha=0.8, label='PCA', color='blue')

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Coordenada x', fontsize=15)
plt.ylabel('Coordenada y', fontsize=15)

plt.legend(fontsize=12)
plt.grid()

plt.show()

# %% [markdown]
# ![Captura de Pantalla 2024-09-05 a la(s) 5.58.36 p.m..png](data:image/png;base64,...)

# %%
import numpy as np

x=np.array([[-.577,-.577,-.577,1.732],[1,1,-1,-1],[-1,1,1,-1]]).T
print(x)
x_var=np.var(x,axis=0)
print(x_var)

z=np.array([[-.4079],[-1.4079],[-.4079],[2.2245]])
z_mean=np.mean(z)
#print(z_mean)
_z1=(z-z_mean)**2
#print(_z1)
var_z1=np.sum(_z1)*(1/3)

print(var_z1)
# Out:
# [[-0.577  1.    -1.   ]
#  [-0.577  1.     1.   ]
#  [-0.577 -1.     1.   ]
#  [ 1.732 -1.    -1.   ]]
# [0.99965269 1.         1.        ]
# 2.421115773333333
